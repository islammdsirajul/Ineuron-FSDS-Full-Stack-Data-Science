# %%
import pandas as pd

# %%
df=pd.read_excel(r"E:\Files\Data science\ineuron full stack datascience paid course\Pandas\First class pandas\Attribute DataSet.xlsx")

# %%
pd.read_excel(r"Attribute DataSet.xlsx", sheet_name = "Sheet2")
# Out:
#   jhjhlkh okkkjj
# 0   uhuih     hh
# 1   uihuh   zugz

# %%
pd.read_excel(r"Attribute DataSet.xlsx", sheet_name = "Sheet2", header= None, names=["A","B","C"])
# Out:
#          A       B   C
# 0  jhjhlkh  okkkjj NaN
# 1    uhuih      hh NaN
# 2    uihuh    zugz NaN

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.tail(2)
#last record
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
# csv format , comma separated format

# %%
#reading file and header er nam change
pd.read_csv("haberman.csv", header=None, names=["age", "Patient's year of operation", "Number of positive", "Survival status "])
# Out:
#      age  Patient's year of operation  Number of positive  Survival status
# 0     30                           64                   1                 1
# 1     30                           62                   3                 1
# 2     30                           65                   0                 1
# 3     31                           59                   2                 1
# 4     31                           65                   4                 1
# ..   ...                          ...                 ...               ...
# 301   75                           62                   1                 1
# 302   76                           67                   0                 1
# 303   77                           65                   3                 1
# 304   78                           65                   1                 2
# 305   83                           58                   2                 2
#
# [306 rows x 4 columns]

# %%
# Separator er maddome change kora 
pd.read_csv("haberman11.csv", sep="@", header=None)
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/Prestige.csv")
# Out:
#      education  income  women  prestige  census  type
# 0        13.11   12351  11.16      68.8    1113  prof
# 1        12.26   25879   4.02      69.1    1130  prof
# 2        12.77    9271  15.70      63.4    1171  prof
# 3        11.42    8865   9.11      56.8    1175  prof
# 4        14.62    8403  11.68      73.5    2111  prof
# ..         ...     ...    ...       ...     ...   ...
# 97        7.58    5562   9.47      35.9    9171    bc
# 98        7.93    4224   3.59      25.1    9173    bc
# 99        8.37    4753   0.00      26.1    9313    bc
# 100      10.00    6462  13.58      42.2    9511    bc
# 101       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 6 columns]

# %%
a=pd.read_html("https://www.iplt20.com/stats")

# %%
a
# Out:
# [                                                   0  \
#  0                                               Role
#  1                                               Bats
#  2                                                NaN
#  3                                                Bio
#  4  A 22-year old opening batsman who hails from P...
#
#                                                     1  \
#  0                                            Batsman
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4  A 22-year old opening batsman who hails from P...
#
#                                                     2  \
#  0                                        Nationality
#  1                                              Bowls
#  2                                                NaN
#  3                                                NaN
# ...

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#                                                    0  \
# 0                                               Role
# 1                                               Bats
# 2                                                NaN
# 3                                                Bio
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    1  \
# 0                                            Batsman
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    2  \
# 0                                        Nationality
# 1                                              Bowls
# 2                                                NaN
# 3                                                NaN
# ...

# %%
js=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
js["user"][0]
# Out:
# {'login': 'MarcoGorelli',
#  'id': 33491632,
#  'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/MarcoGorelli',
#  'html_url': 'https://github.com/MarcoGorelli',
#  'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#  'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#  'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#  'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#  'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
# ...

# %%
df=pd.read_excel(r"Attribute DataSet.xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#converting excel data into json data
df.to_json("test.json")

# %%
pwd
# Out:
# 'C:\\Users\\Md Sirajul Islam\\Full Stack DataScience Paid Ineuron\\Module 1 python\\Pandas'

# %%
df=pd.read_excel(r"Attribute DataSet.xlsx")

# %%
df.to_csv("E://Files")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:385, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     384 try:
# --> 385     file_obj = fsspec.open(
#     386         filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
#     387     ).open()
#     388 # GH 34626 Reads from Public Buckets without Credentials needs anon=True
#
# File ~\anaconda3\lib\site-packages\fsspec\core.py:140, in OpenFile.open(self)
#     133 """Materialise this as a real open file without context
#     134
#     135 The file should be explicitly closed to avoid enclosed file
#    (...)
#     138 been deleted; but a with-context is better style.
#     139 """
# --> 140 out = self.__enter__()
#     141 closer = out.close
#
# ...

# %%
df.to_CSV("E://test123.csv", sep= "#")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 df.to_CSV("E://test123.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_CSV'

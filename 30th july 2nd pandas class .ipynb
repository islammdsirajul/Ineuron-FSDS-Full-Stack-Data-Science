# %%
import pandas as pd

# %%
df= pd.read_csv("sales_data_final.csv ")

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df["order_id"]
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
type(df["order_id"])
# Out:
# pandas.core.series.Series

# %%
#only two types of data set in pandas , one data series (list), another data frame (table)

# %%
df.dtypes
"""data type of every column, 
object = string, quantity = int, float= float"""
# Out:
# 'data type of every column, \nobject = string, quantity = int, float= float'

# %%
df["profit"]
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
#            ...
# 51285      4.5188
# 51286      0.4200
# 51287     12.3600
# 51288      0.5600
# 51289     -0.6048
# Name: profit, Length: 51290, dtype: float64

# %%
type(df["profit"])
# Out:
# pandas.core.series.Series

# %%
type(df[["profit"]])
# Out:
# pandas.core.frame.DataFrame

# %%
"""if we hv more than one column u pass column name as list parameter otherwise it will give error """
# Out:
# 'if we hv more than one column u pass column name as list parameter otherwise it will give error '

# %%
df[["profit", "year"]]
"""for data of multiple column
use two square bracket, and it will create a list of columns"""
# Out:
# 'for data of multiple column\nuse two square bracket, and it will create a list of columns'

# %%
df[["order_date","product_id", "quantity"]]

#"""try to fetch data of few columns"""
# Out:
#        order_date        product_id  quantity
# 0        1/1/2011  OFF-TEN-10000025         2
# 1        1/1/2011   OFF-SU-10000618         3
# 2        1/1/2011  OFF-TEN-10001585         4
# 3        1/1/2011   OFF-PA-10001492         3
# 4        1/1/2011   FUR-FU-10003447         5
# ...           ...               ...       ...
# 51285  12/31/2014   OFF-BI-10002103         2
# 51286  12/31/2014  OFF-WIL-10001069         1
# 51287  12/31/2014   OFF-LA-10004182         3
# 51288  12/31/2014   OFF-LA-10000413         1
# 51289  12/31/2014   OFF-FA-10003472         3
#
# [51290 rows x 3 columns]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.describe()
#to get some statistics, it give only int or float number er results, not any object
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
"""
pandas profiling
count: it is only fiving description of numeric data column, 
for count we can see whether we have null value or not bcz all of this column has number of data equal
mean: avg, avg quantity of order is 
std standard deviation: square root of variances, deviation from the mean, 
min: minimum quantity 
25% 25 th percentile of the data,
50%
75%
"""
# Out:
# '\npandas profiling\ncount: it is only fiving description of numeric data column, \nfor count we can see whether we have null value or not bcz all of this column has number of data equal\nmean: avg, avg quantity of order is \nstd standard deviation: square root of variances, deviation from the mean, \nmin: minimum quantity \n25% 25 th percentile of the data,\n50%\n75%\n'

# %%
#only those data where data type is object 
df.dtypes == "object"
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df.dtypes[df.dtypes == "object"].index].describe()
# description of object data type finding process
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
type (df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes[df.dtypes=="float64"].index
# Out:
# Index(['discount', 'profit', 'shipping_cost'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="float64"].index]
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.order_id
# series is a list
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df["order_id"]
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df["order_id"][1:40:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
#adding new column in dataframe

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df["category"]
# Out:
# 0        Office Supplies
# 1        Office Supplies
# 2        Office Supplies
# 3        Office Supplies
# 4              Furniture
#               ...
# 51285    Office Supplies
# 51286    Office Supplies
# 51287    Office Supplies
# 51288    Office Supplies
# 51289    Office Supplies
# Name: category, Length: 51290, dtype: object

# %%
df["category1"]="sudh"

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df["order_id"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: order_id, Length: 51290, dtype: bool

# %%
df1= pd.read_excel("Dress Sales.xlsx")

# %%
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df1.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00],
#       dtype='object')

# %%
df1["Dress_ID"]
# Out:
# 0      1006032852
# 1      1212192089
# 2      1190380701
# 3       966005983
# 4       876339541
#           ...
# 495     713391965
# 496     722565148
# 497     532874347
# 498     655464934
# 499     919930954
# Name: Dress_ID, Length: 500, dtype: int64

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#give me a person name who has maximum profit

# %%
df[df["profit"]== max(df["profit"])]["customer_name"]
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df["country"]
# Out:
# 0              Algeria
# 1            Australia
# 2              Hungary
# 3               Sweden
# 4            Australia
#              ...
# 51285    United States
# 51286          Morocco
# 51287        Nicaragua
# 51288           Mexico
# 51289    United States
# Name: country, Length: 51290, dtype: object

# %%
#record for a country can u filterout all the data of sweeden
df[df["country"]== "Sweden"]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %%
# how many orders we have got from sweden

# %%
len(df[df["country"]== "Sweden"])
# Out:
# 203

# %%
#shipment cost was more than 10 dollar

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df[df["shipping_cost"]>80]
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 7       IN-2011-79397    1/3/2011  1/3/2011        Same Day
# 8       ID-2011-80230    1/3/2011  1/9/2011  Standard Class
# 9        IZ-2011-4680    1/3/2011  1/7/2011  Standard Class
# 27     MX-2011-111255    1/4/2011  1/9/2011    Second Class
# 43     MX-2011-109267    1/5/2011  1/9/2011  Standard Class
# ...               ...         ...       ...             ...
# 51154   IN-2014-49206  12/30/2014  1/1/2015    Second Class
# 51228  MX-2014-116267  12/31/2014  1/3/2015    Second Class
# 51229   IN-2014-43550  12/31/2014  1/1/2015     First Class
# 51230    RS-2014-1460  12/31/2014  1/2/2015    Second Class
# 51231   IN-2014-30390  12/31/2014  1/3/2015     First Class
#
#              customer_name    segment            state      country market  \
# 7              Kean Nguyen  Corporate  New South Wales    Australia   APAC
# 8             Ken Lonsdale   Consumer         Auckland  New Zealand   APAC
# ...

# %%
#can u give me the list of all the countries

# %%
df[df["shipping_cost"]>80]["country"]
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %%
#can u find shipment cost is more than 100 dollar and profit is lesst than 10 dollar

# %%
df[(df["shipping_cost"])>100 & (df["profit"]<10)]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[["profit","customer_name"]].max()
# Out:
# profit                     8399.976
# customer_name    Zuschuss Donatelli
# dtype: object

# %%
##date time conversion: 
# changing object data type to date time format ,  date or year, month opearation

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# category1          object
# dtype: object

# %%
df["order_date"]
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
pd.to_datetime(df["order_date"])
#to_datetime is a function, tai jokhoni function call korbo tahole ()bracket asbe pore
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
date=pd.to_datetime(df["order_date"])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#create new column and store time data into new columndf[""]

# %%
df["converted_order_date"] = pd.to_datetime(df["order_date"])

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# ...

# %%
#only year extract from this column

# %%
df["order_date_year"]=df["converted_order_date"].dt.year

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# ...

# %%
df["order_date_month"]=df["converted_order_date"].dt.month

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# ...

# %%
df["order_date_week"]=df["converted_order_date"].dt.week
# Out:
# C:\Users\Md Sirajul Islam\AppData\Local\Temp\ipykernel_156324\3813256015.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["order_date_week"]=df["converted_order_date"].dt.week

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# ...

# %%
df[["converted_order_date","order_date_week"]]
# Out:
#       converted_order_date  order_date_week
# 0               2011-01-01               52
# 1               2011-01-01               52
# 2               2011-01-01               52
# 3               2011-01-01               52
# 4               2011-01-01               52
# ...                    ...              ...
# 51285           2014-12-31                1
# 51286           2014-12-31                1
# 51287           2014-12-31                1
# 51288           2014-12-31                1
# 51289           2014-12-31                1
#
# [51290 rows x 2 columns]

# %%
df[df["order_date_year"]==2014]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
#in which month sales was more

# %%
df["order_date_month"].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'converted_order_date', 'order_date_year',
#        'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
#cost of company by creating new column, shipping cost plus discount

# %%
df["cost_to_comapany"]= df["discount"]+df["shipping_cost"]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
#   shipping_cost order_priority  year category1  converted_order_date  \
# ...

# %%
#finding cost to company high for which product_id

# %%
df[df["cost_to_comapany"]==max(df["cost_to_comapany"])]["product_name"]
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
df.drop("cost_to_comapany",axis=1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
#   shipping_cost order_priority  year category1  converted_order_date  \
# ...

# %%
#drop diye sudhu current data frame theke column delete hoy , but main dataframe e theke jay
# tai dataframe k define korle full new data frame hobe

# %%
df=df.drop("cost_to_comapany",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [192], in <cell line: 1>()
# ----> 1 df=df.drop("cost_to_comapany",axis=1,inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
#drop raw

# %%
df.drop(1, inplace=True)
#but it is not permanently dropped 
#to drop permanenently we can use inplace=True

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
### column operation<: column theke filter out record
# condition use in column, we have already learnt

# %%
###Raw operations
#loc , iloc, axis er maddome kora jay

# %%
# show raw 2and 3
df.loc[[2,3]]
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... discount  profit  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...      0.0  29.640
# 3  Home Office  Stockholm   Sweden     EU  North  ...      0.5 -26.055
#
#   shipping_cost order_priority  year  category1  converted_order_date  \
# 2          8.17           High  2011       sudh            2011-01-01
# 3          4.82           High  2011       sudh            2011-01-01
#
#    order_date_year  order_date_month order_date_week
# 2             2011                 1              52
# 3             2011                 1              52
#
# [2 rows x 26 columns]

# %%
#filtering recored starting from range

df.loc[2:10]
# Out:
#            order_id order_date ship_date       ship_mode     customer_name  \
# 2      HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3   IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5     IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6      CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7     IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8     ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9      IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
# 10    IN-2011-65159   1/3/2011  1/7/2011    Second Class      Larry Blacks
#
#         segment             state      country  market          region  ...  \
# 2      Consumer          Budapest      Hungary    EMEA            EMEA  ...
# ...

# %%
#try to filterout data in a range with jump
df.loc[2:10:2]
# Out:
#          order_id order_date ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4   IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6    CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159   1/3/2011  1/7/2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#    discount    profit shipping_cost order_priority  year  category1  \
# ...

# %%
#filtering out just a part of record
df.loc[0:4, ["order_id","order_date","ship_date"]]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
#different between iloc and loc
#loc takes named indexes that u can see in screen , location
#iloc understand default indexes, hidden indexes, internal indexes0,1,2,3
#iloc not only number it understand default internal indexes
df.iloc[0:4,0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#extracting record from the middle of the dataframe
#2:5 is raw first er ta raw, second er ta column 3:6
df.iloc[2:5,3:6]
# Out:
#         ship_mode customer_name      segment
# 3    Second Class  Eugene Moren  Home Office
# 4  Standard Class   Joseph Holt     Consumer
# 5  Standard Class   Joseph Holt     Consumer

# %%
#filter operation in whole dataframe
#record where numbers greater than 100

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                           object
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# category1                       object
# converted_order_date    datetime64[ns]
# order_date_year                  int64
# ...

# %%
df.dtypes[(df.dtypes == "float64") | (df.dtypes=="int64")]
# Out:
# quantity              int64
# discount            float64
# profit              float64
# shipping_cost       float64
# year                  int64
# order_date_year       int64
# order_date_month      int64
# order_date_week       int64
# dtype: object

# %%
df.dtypes[df.dtypes!=object]
# Out:
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# year                             int64
# converted_order_date    datetime64[ns]
# order_date_year                  int64
# order_date_month                 int64
# order_date_week                  int64
# dtype: object

# %%
#to find indexes
df.dtypes[(df.dtypes == "float64") | (df.dtypes=="int64")].index
# Out:
# Index(['quantity', 'discount', 'profit', 'shipping_cost', 'year',
#        'order_date_year', 'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
#to filter out data of this indexes
df2=df[df.dtypes[(df.dtypes == "float64") | (df.dtypes=="int64")].index]

# %%
df2
# Out:
#        quantity  discount    profit  shipping_cost  year  order_date_year  \
# 0             2       0.0  106.1400          35.46  2011             2011
# 2             4       0.0   29.6400           8.17  2011             2011
# 3             3       0.5  -26.0550           4.82  2011             2011
# 4             5       0.1   37.7700           4.70  2011             2011
# 5             2       0.1   15.3420           1.80  2011             2011
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             2014
# 51286         1       0.0    0.4200           0.49  2014             2014
# 51287         3       0.0   12.3600           0.35  2014             2014
# 51288         1       0.0    0.5600           0.20  2014             2014
# 51289         3       0.2   -0.6048           0.17  2014             2014
#
#        order_date_month  order_date_week
# ...

# %%
df2[df2>100]
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3=df2[df2>100]

# %%
 df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
#drop record where null values 'nan'

# %%
df3.dropna()
#it delted all bcz all the raw have at least one null value
#by deafualut dropna work with axis=0 raw based .so, it will drop all the raw with at least one null values
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, order_date_month, order_date_week]
# Index: []

# %%
df3.dropna(axis=1)
#only two columns where we have no null values
# Out:
#        year  order_date_year
# 0      2011             2011
# 2      2011             2011
# 3      2011             2011
# 4      2011             2011
# 5      2011             2011
# ...     ...              ...
# 51285  2014             2014
# 51286  2014             2014
# 51287  2014             2014
# 51288  2014             2014
# 51289  2014             2014
#
# [51289 rows x 2 columns]

# %%
#applying condition: wherever if i have more than 5 nan values drop it , otherwise dont drop#
#thresh dekhbe koto ta non nan value ase
df3.dropna(thresh =3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
#fill data in NaN values
#fillna using, jekhane ee nan value ase sekhane new value dibe
df3.fillna(value=4)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           4.0       4.0  106.14            4.0  2011             2011
# 2           4.0       4.0    4.00            4.0  2011             2011
# 3           4.0       4.0    4.00            4.0  2011             2011
# 4           4.0       4.0    4.00            4.0  2011             2011
# 5           4.0       4.0    4.00            4.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014             2014
# 51286       4.0       4.0    4.00            4.0  2014             2014
# 51287       4.0       4.0    4.00            4.0  2014             2014
# 51288       4.0       4.0    4.00            4.0  2014             2014
# 51289       4.0       4.0    4.00            4.0  2014             2014
#
#        order_date_month  order_date_week
# 0                   4.0              4.0
# ...

# %%
# fillling NaN with average of column
df3.fillna(value=df3["profit"].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# 5      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        order_date_year  order_date_month  order_date_week
# 0                 2011        285.710477       285.710477
# 2                 2011        285.710477       285.710477
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#treatment of sales column where comma change
df["sales"]=df.sales.str.replace(",","").astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [257], in <cell line: 2>()
#       1 #treatment of sales column where comma change
# ----> 2 df["sales"]=df.sales.str.replace(",","").astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
#yearly average profit
#on an average profit in 2011,2012 etc
#first group it basedon years

# %%
df.groupby("order_date_year")["profit"] . mean()
# Out:
# order_date_year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby("order_date_year")["shipping_cost"] . mean()
# Out:
# order_date_year
# 2011    27.149201
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df.groupby("order_date_year")["discount"] . mean()
# Out:
# order_date_year
# 2011    0.148193
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.groupby("order_date_year")["sales"] . mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby("order_date_year")["quantity"] . sum()
# Out:
# order_date_year
# 2011    31440
# 2012    38111
# 2013    48136
# 2014    60622
# Name: quantity, dtype: int64

# %%
df.groupby("order_date_year")["sales"] . sum()
# Out:
# order_date_year
# 2011    2259391
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'converted_order_date', 'order_date_year',
#        'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
https://drive.google.com/file/d/1FRnbQqgK6S-mr9StNF5MurSaXhah9uoJ/view?usp=sharing


https://drive.google.com/file/d/11rPJXr-9VoeV2Pi0RSfVehw1tbQOAjLI/view?usp=sharing

https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true


https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true

1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
2 .Total working days for each agents 
3. Total query that you hvae taken 
4. total Feedback that you have received 
5. a agent name who have average rating between 3.5 to 4 
6 . Agent name who have rating lesss then 3.5 
7 . agent name who have rating more then 4.5 
8 . how many feedaback agents have received more then 4.5 average
9 . average weekly response time for each agent 
10 . average weekely resolution time for each agents 
11 . list of all agents name 
12 . percentage of chat on which they have received a feedback 
13 . Total contributation hour for each and every agents weekly basis 
14. total percentage of active hour for a month 

sunny.savita@ineuron.ai ,sudhanshu@ineuron.ai

deadline of complition of this task is 12 AM IST today 

After that if you will submit your task i wont evaluate it at all , excuses will be given to new 
joiners
